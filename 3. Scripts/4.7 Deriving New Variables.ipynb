# %% [markdown]
# 4.7 Deriving New Variables

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
#Set OS Path
path = r'/Users/faridchehraz/Desktop/Python/Master - Dec2021 Instacart Basket Analysis'

# %%
#Import ords_prods_merged  pkl file
df_ords_prods_merged = pd.read_pickle(os.path.join(path, '2. Data', 'b. Prepared Data', 'orders_products_merged.pkl'))

# %%
#Limit the DF to 1 million rows
df = df_ords_prods_merged[:1000000]

# %%
#Check the shape of the sample
df.shape
# Out:
# (1000000, 15)

# %%
#Set up conditions of the If-statement
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return np.nan

# %%
#Add the results of the If-statement as a column to the DF
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# /var/folders/vh/d2rsnjw92ql_ggn35h8q4vmr0000gn/T/ipykernel_1961/1061111531.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
#Count the instances of the price groups
df['price_range'].value_counts (dropna = False)
# Out:
# Mid-range product    672525
# Low-range product    314109
# High range            12413
# NaN                     953
# Name: price_range, dtype: int64

# %%
#Check the highest price
df['prices'].max()
# Out:
# 99999.0

# %%
#If-statement with the loc() function
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
#If-statement with the loc() function
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
#If-statement with the loc() function
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
#Count the instances of the price groups
df['price_range'].value_counts (dropna = False)
# Out:
# Mid-range product    672525
# Low-range product    314109
# High range            12413
# NaN                     953
# Name: price_range, dtype: int64

# %%
#Adding the If-statement with the loc() function to the DF
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
#Adding the If-statement with the loc() function to the DF
df_ords_prods_merged.loc[(df_ords_prods_merged['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
#Adding the If-statement with the loc() function to the DF
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
#Count the instances of the price groups
df_ords_prods_merged['price_range_loc'].value_counts (dropna = False)
# Out:
# NaN                   21218535
# Low-range product     10126321
# Mid-range product       672525
# High-range product      417678
# Name: price_range_loc, dtype: int64

# %%
#Check a sample of the output with the new price group column
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both
#
# ...

# %%
#Check which are the busiest days of the week
df_ords_prods_merged['orders_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6209808
# 1    5665951
# 6    4500391
# 2    4217868
# 5    4209603
# 3    3844175
# 4    3787263
# Name: orders_day_of_week, dtype: int64

# %%
#Create a result list which puts days into 3 categories of business
result = []

for value in df_ords_prods_merged["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
#Show list 'result' created above
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
#Add result list as a column to the DF
df_ords_prods_merged['busiest_day'] = result

# %%
#Count the instances of the day business groups
df_ords_prods_merged['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    22437988
# Busiest day        6209808
# Least busy         3787263
# Name: busiest_day, dtype: int64

# %%
#Create a result list which puts days into 3 new categories of business
result2 = []

for value in df_ords_prods_merged["orders_day_of_week"]:
  if (value == 0) or (value == 1):
    result2.append("Busiest days")
  elif (value == 4) or (value == 3):
    result2.append("Least busy days")
  else:
    result2.append("Regularly busy days")

# %%
#Show list 'result2' created above
result2
# Out:
# ['Regularly busy days',
#  'Regularly busy days',
#  'Regularly busy days',
#  'Regularly busy days',
#  'Regularly busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Regularly busy days',
#  'Regularly busy days',
#  'Regularly busy days',
#  'Regularly busy days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
# ...

# %%
#Add result list as a column to the DF
df_ords_prods_merged['busiest_days'] = result2

# %%
#Count the instances of the day business groups new list
df_ords_prods_merged['busiest_days'].value_counts(dropna = False)
# Out:
# Regularly busy days    12927862
# Busiest days           11875759
# Least busy days         7631438
# Name: busiest_days, dtype: int64

# %% [markdown]
# New column ties in with initial count of business days in output 23

# %%
#Check which are the busiest hours of the day
df_ords_prods_merged['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    2764476
# 11    2738647
# 14    2691598
# 15    2664583
# 13    2663346
# 12    2620898
# 16    2537506
# 9     2456751
# 17    2089510
# 8     1719991
# 18    1637956
# 19    1259416
# 20     977049
# 7      891951
# 21     796379
# 22     634743
# 23     402621
# 6      290796
# 0      218951
# 1      115787
# 5       88064
# 2       69435
# 4       53284
# 3       51321
# Name: order_hour_of_day, dtype: int64

# %%
#Create a result list which puts hours into 3 categories
result3 = []

for value in df_ords_prods_merged["order_hour_of_day"]:
  if (value >= 9) and (value <= 16):
    result3.append("Most orders")
  elif (value == 7) or (value == 8):
    result3.append("Average orders")
  elif (value >= 17) and (value <= 22):
    result3.append("Average orders")
  else:
    result3.append("Fewest orders")

# %%
#Show list 'result3' created above
result3
# Out:
# ['Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
# ...

# %%
#Add result list as a column to the DF
df_ords_prods_merged['busiest_period_of_day'] = result3

# %%
#Count the instances of the busiest hour groups  list
df_ords_prods_merged['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# Most orders       21137805
# Average orders    10006995
# Fewest orders      1290259
# Name: busiest_period_of_day, dtype: int64

# %% [markdown]
# New column ties in with initial count of hours in output 53

# %%
#Export merged DF as orders_products_merged_analysis.pkl
df_ords_prods_merged.to_pickle(os.path.join(path, '2. Data', 'b. Prepared Data', 'orders_products_merged_analysis.pkl'))
